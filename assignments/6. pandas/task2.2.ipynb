# %% [markdown]
# yakina_data.csv

# %%
import pandas as pd

# %%
y = pd.read_csv('./datasets/task_2/yakina_data.csv')
y[20:29]
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 20        45  '2020/12/20'     97       125     243.0
# 21        60  '2020/12/21'    108       131     364.2
# 22        45           NaN    100       119     282.0
# 23        60  '2020/12/23'    130       101     300.0
# 24        45  '2020/12/24'    105       132     246.0
# 25        60  '2020/12/25'    102       126     334.5
# 26        60      20201226    100       120     250.0
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132       NaN

# %% [markdown]
# find what data types the dataframe have

# %%
y.dtypes
# Out:
# Duration      int64
# Date         object
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %% [markdown]
# 1. convert the odd string in Date column to a format like others.

# %%
odd_format = y['Date'].str.len() == 8
y.loc[odd_format, 'Date'] = y.loc[odd_format, 'Date'].apply(lambda x: f'{x[:4]}/{x[4:6]}/{x[6:]}')
y[22:]
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 22        45           NaN    100       119     282.0
# 23        60  '2020/12/23'    130       101     300.0
# 24        45  '2020/12/24'    105       132     246.0
# 25        60  '2020/12/25'    102       126     334.5
# 26        60    2020/12/26    100       120     250.0
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132       NaN
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %% [markdown]
# 2. Then convert the Date column to a datetime object.

# %%
y['Date'] = pd.to_datetime(y['Date'], format='mixed')
y.dtypes
# Out:
# Duration             int64
# Date        datetime64[ns]
# Pulse                int64
# Maxpulse             int64
# Calories           float64
# dtype: object

# %% [markdown]
# 3. Find if there are any duplicates

# %%
print(y.duplicated().sum())
# Out:
# 1

# %% [markdown]
# 4. Drop the duplicate and fix the missing index afterward.

# %%
y[10:15]
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3

# %%
y = y.drop_duplicates().reset_index(drop=True)
print(y.duplicated().sum())
y[10:15]
# Out:
# 0
#     Duration       Date  Pulse  Maxpulse  Calories
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-13    106       128     345.3
# 13        60 2020-12-14    104       132     379.3
# 14        60 2020-12-15     98       123     275.0

# %% [markdown]
# 5. There is an anomalous value in the data. Replace it.

# %%
median = y["Duration"].median()
std = y["Duration"].std()
outliers = (y["Duration"] - median).abs() > std
outliers[3:10]
# Out:
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# Name: Duration, dtype: bool

# %%
y[3:10]
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories
# 3        45 2020-12-04    109       175     282.4
# 4        45 2020-12-05    117       148     406.0
# 5        60 2020-12-06    102       127     300.0
# 6        60 2020-12-07    110       136     374.0
# 7       450 2020-12-08    104       134     253.3
# 8        30 2020-12-09    109       133     195.1
# 9        60 2020-12-10     98       124     269.0

# %%
y.loc[outliers, 'Duration'] = median
y[3:10]
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories
# 3        45 2020-12-04    109       175     282.4
# 4        45 2020-12-05    117       148     406.0
# 5        60 2020-12-06    102       127     300.0
# 6        60 2020-12-07    110       136     374.0
# 7        60 2020-12-08    104       134     253.3
# 8        30 2020-12-09    109       133     195.1
# 9        60 2020-12-10     98       124     269.0

# %% [markdown]
# 6. Create a column that finds difference in Max Pulse and pulse

# %%
y['Maxpulse - Pulse'] = y['Maxpulse'] - y['Pulse']
y.head()
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories  Maxpulse - Pulse
# 0        60 2020-12-01    110       130     409.1                20
# 1        60 2020-12-02    117       145     479.0                28
# 2        60 2020-12-03    103       135     340.0                32
# 3        45 2020-12-04    109       175     282.4                66
# 4        45 2020-12-05    117       148     406.0                31

# %% [markdown]
# 7. Find how many calories they burned per second.

# %%
y['Calories per Second'] = y['Calories'] / y['Duration']
y.head()
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories  Maxpulse - Pulse  \
# 0        60 2020-12-01    110       130     409.1                20
# 1        60 2020-12-02    117       145     479.0                28
# 2        60 2020-12-03    103       135     340.0                32
# 3        45 2020-12-04    109       175     282.4                66
# 4        45 2020-12-05    117       148     406.0                31
#
#    Calories per Second
# 0             6.818333
# 1             7.983333
# 2             5.666667
# 3             6.275556
# 4             9.022222

# %% [markdown]
# 8. Sort the data frame by calories..

# %%
y.sort_values(by=['Calories']).head()
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories  Maxpulse - Pulse  \
# 8         30 2020-12-09    109       133     195.1                24
# 15        60 2020-12-16     98       120     215.2                22
# 26        60 2020-12-27     92       118     241.0                26
# 19        45 2020-12-20     97       125     243.0                28
# 30        60 2020-12-31     92       115     243.0                23
#
#     Calories per Second
# 8              6.503333
# 15             3.586667
# 26             4.016667
# 19             5.400000
# 30             4.050000

# %% [markdown]
# 9. Retrieve a subset of the dataframes where calories are higher than 400, less than 200 and between 200-300.

# %%
high_calories = y[y['Calories'] > 400]
low_calories = y[y['Calories'] < 200]
medium_calories = y[(y['Calories'] >= 200) & (y['Calories'] <= 300)]

# %%
high_calories
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories  Maxpulse - Pulse  \
# 0        60 2020-12-01    110       130     409.1                20
# 1        60 2020-12-02    117       145     479.0                28
# 4        45 2020-12-05    117       148     406.0                31
#
#    Calories per Second
# 0             6.818333
# 1             7.983333
# 4             9.022222

# %%
low_calories
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories  Maxpulse - Pulse  \
# 8        30 2020-12-09    109       133     195.1                24
#
#    Calories per Second
# 8             6.503333

# %%
medium_calories
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories  Maxpulse - Pulse  \
# 3         45 2020-12-04    109       175     282.4                66
# 5         60 2020-12-06    102       127     300.0                25
# 7         60 2020-12-08    104       134     253.3                30
# 9         60 2020-12-10     98       124     269.0                26
# 11        60 2020-12-12    100       120     250.7                20
# 14        60 2020-12-15     98       123     275.0                25
# 15        60 2020-12-16     98       120     215.2                22
# 16        60 2020-12-17    100       120     300.0                20
# 19        45 2020-12-20     97       125     243.0                28
# 21        45        NaT    100       119     282.0                19
# 22        60 2020-12-23    130       101     300.0               -29
# 23        45 2020-12-24    105       132     246.0                27
# 25        60 2020-12-26    100       120     250.0                20
# ...

# %% [markdown]
# 10. Find Unique values in duration

# %%
print(y['Duration'].unique())
# Out:
# [60 45 30]

# %% [markdown]
# 11. Count how many missing values are there in the dataframe.

# %%
y.isnull().sum()
# Out:
# Duration               0
# Date                   1
# Pulse                  0
# Maxpulse               0
# Calories               2
# Maxpulse - Pulse       0
# Calories per Second    2
# dtype: int64

# %%
y
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories  Maxpulse - Pulse  \
# 0         60 2020-12-01    110       130     409.1                20
# 1         60 2020-12-02    117       145     479.0                28
# 2         60 2020-12-03    103       135     340.0                32
# 3         45 2020-12-04    109       175     282.4                66
# 4         45 2020-12-05    117       148     406.0                31
# 5         60 2020-12-06    102       127     300.0                25
# 6         60 2020-12-07    110       136     374.0                26
# 7         60 2020-12-08    104       134     253.3                30
# 8         30 2020-12-09    109       133     195.1                24
# 9         60 2020-12-10     98       124     269.0                26
# 10        60 2020-12-11    103       147     329.3                44
# 11        60 2020-12-12    100       120     250.7                20
# 12        60 2020-12-13    106       128     345.3                22
# ...

# %%
# y.dropna(inplace=True)
